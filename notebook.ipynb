# %%
2 + 2
# Out:
# 4

# %%
value = 3

# %%
value
# Out:
# 3

# %%
inna_nazwa = "Tekst"

# %%
inna_nazwa
# Out:
# 'Tekst'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
"Tekst"
# Out:
# 'Tekst'
